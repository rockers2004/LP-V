# %%
# =========================================================
# GOOGLE STOCK PRICE PREDICTION USING LSTM AND GRU
# =========================================================

# =====================
# IMPORT LIBRARIES
# =====================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dropout

# =====================
# LOAD DATASET
# =====================

df = pd.read_csv("googl_data_2020_2025.csv")

print(df.head())

# =====================
# CLEAN DATASET
# =====================

# Remove unwanted rows
df = df.iloc[2:].reset_index(drop=True)

# Rename column
df.rename(columns={'Price':'Date'}, inplace=True)

# Convert date column
df['Date'] = pd.to_datetime(df['Date'])

# Convert numeric columns
numeric_cols = ['Adj Close', 'Close',
                'High', 'Low',
                'Open', 'Volume']

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col],
                            errors='coerce')

# Remove null values
df.dropna(inplace=True)

print(df.head())

# =====================
# VISUALIZE DATA
# =====================

plt.figure(figsize=(14,6))

plt.plot(df['Date'], df['Close'])

plt.title('Google Stock Closing Price')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.grid(True)
plt.show()

# =====================
# PREPARE DATA
# =====================

data = df[['Close']]

# Normalize data
scaler = MinMaxScaler(feature_range=(0,1))

scaled_data = scaler.fit_transform(data)

# =====================
# CREATE SEQUENCES
# =====================

X = []
y = []

sequence_length = 60

for i in range(sequence_length,
               len(scaled_data)):

    X.append(
        scaled_data[i-sequence_length:i, 0]
    )

    y.append(scaled_data[i, 0])

X = np.array(X)
y = np.array(y)

# Reshape for RNN
X = np.reshape(
    X,
    (X.shape[0], X.shape[1], 1)
)

print(X.shape)
print(y.shape)

# =====================
# TRAIN TEST SPLIT
# =====================

split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# =========================================================
# LSTM MODEL
# =========================================================

print("\n========================")
print("TRAINING LSTM MODEL")
print("========================")

lstm_model = Sequential()

# First LSTM Layer
lstm_model.add(
    LSTM(
        units=50,
        return_sequences=True,
        input_shape=(X_train.shape[1],1)
    )
)

lstm_model.add(Dropout(0.2))

# Second LSTM Layer
lstm_model.add(
    LSTM(
        units=50,
        return_sequences=True
    )
)

lstm_model.add(Dropout(0.2))

# Third LSTM Layer
lstm_model.add(LSTM(units=50))

lstm_model.add(Dropout(0.2))

# Output Layer
lstm_model.add(Dense(units=1))

# Compile
lstm_model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

lstm_model.summary()

# Train
lstm_history = lstm_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# =====================
# LSTM PREDICTIONS
# =====================

lstm_predictions = lstm_model.predict(X_test)

lstm_predictions = scaler.inverse_transform(
    lstm_predictions
)

real_prices = scaler.inverse_transform(
    y_test.reshape(-1,1)
)

# =====================
# LSTM EVALUATION
# =====================

lstm_mse = mean_squared_error(
    real_prices,
    lstm_predictions
)

lstm_rmse = np.sqrt(lstm_mse)

lstm_mae = mean_absolute_error(
    real_prices,
    lstm_predictions
)

lstm_mape = mean_absolute_percentage_error(
    real_prices,
    lstm_predictions
)

lstm_accuracy = 100 - (lstm_mape * 100)

print("\n======= LSTM RESULTS =======")

print("LSTM RMSE :", lstm_rmse)
print("LSTM MAE :", lstm_mae)

print(
    "LSTM Accuracy : {:.2f}%"
    .format(lstm_accuracy)
)
from sklearn.metrics import r2_score

# Predictions
y_pred = lstm_model.predict(X_test)

# Convert back to original prices
y_pred_actual = scaler.inverse_transform(y_pred)

y_test_actual = scaler.inverse_transform(
    y_test.reshape(-1,1)
)

# R2 Score
r2 = r2_score(y_test_actual, y_pred_actual)

print("R2 Score:", r2)

# =========================================================
# GRU MODEL
# =========================================================

print("\n========================")
print("TRAINING GRU MODEL")
print("========================")

gru_model = Sequential()

# First GRU Layer
gru_model.add(
    GRU(
        units=50,
        return_sequences=True,
        input_shape=(X_train.shape[1],1)
    )
)

gru_model.add(Dropout(0.2))

# Second GRU Layer
gru_model.add(
    GRU(
        units=50,
        return_sequences=True
    )
)

gru_model.add(Dropout(0.2))

# Third GRU Layer
gru_model.add(GRU(units=50))

gru_model.add(Dropout(0.2))

# Output Layer
gru_model.add(Dense(units=1))

# Compile
gru_model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

gru_model.summary()

# Train
gru_history = gru_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# =====================
# GRU PREDICTIONS
# =====================

gru_predictions = gru_model.predict(X_test)

gru_predictions = scaler.inverse_transform(
    gru_predictions
)

# =====================
# GRU EVALUATION
# =====================

gru_mse = mean_squared_error(
    real_prices,
    gru_predictions
)

gru_rmse = np.sqrt(gru_mse)

gru_mae = mean_absolute_error(
    real_prices,
    gru_predictions
)

gru_mape = mean_absolute_percentage_error(
    real_prices,
    gru_predictions
)

gru_accuracy = 100 - (gru_mape * 100)

print("\n======= GRU RESULTS =======")

print("GRU RMSE :", gru_rmse)
print("GRU MAE :", gru_mae)

print(
    "GRU Accuracy : {:.2f}%"
    .format(gru_accuracy)
)
from sklearn.metrics import r2_score

# Predict using GRU model
y_pred_gru = gru_model.predict(X_test)

# Convert predictions back to original scale
y_pred_gru_actual = scaler.inverse_transform(y_pred_gru)

# Convert actual y_test back to original scale
y_test_actual = scaler.inverse_transform(
    y_test.reshape(-1,1)
)

# Calculate R2 Score
gru_r2 = r2_score(
    y_test_actual,
    y_pred_gru_actual
)

print("GRU R2 Score:", gru_r2)

# =========================================================
# COMPARE BOTH MODELS
# =========================================================

print("\n===================================")
print("LSTM vs GRU COMPARISON")
print("===================================")

print("LSTM Accuracy : {:.2f}%"
      .format(lstm_accuracy))

print("GRU Accuracy : {:.2f}%"
      .format(gru_accuracy))

# =========================================================
# VISUALIZATION
# =========================================================

plt.figure(figsize=(14,6))

plt.plot(real_prices,
         color='blue',
         label='Actual Price')

plt.plot(lstm_predictions,
         color='red',
         label='LSTM Prediction')

plt.plot(gru_predictions,
         color='green',
         label='GRU Prediction')

plt.title(
    'Google Stock Price Prediction'
)

plt.xlabel('Time')
plt.ylabel('Stock Price')

plt.legend()
plt.grid(True)

plt.show()

# =========================================================
# FUTURE PREDICTION
# =========================================================

last_60_days = scaled_data[-60:]

X_future = []

X_future.append(last_60_days)

X_future = np.array(X_future)

X_future = np.reshape(
    X_future,
    (
        X_future.shape[0],
        X_future.shape[1],
        1
    )
)

# LSTM Future Prediction
lstm_future = lstm_model.predict(X_future)

lstm_future = scaler.inverse_transform(
    lstm_future
)

# GRU Future Prediction
gru_future = gru_model.predict(X_future)

gru_future = scaler.inverse_transform(
    gru_future
)

print("\n===================================")
print("NEXT DAY STOCK PRICE PREDICTION")
print("===================================")

print("LSTM Predicted Price :",
      lstm_future[0][0])

print("GRU Predicted Price :",
      gru_future[0][0])
# Out:
#                        Price    Adj Close        Close         High  \
# 0                     Ticker        GOOGL        GOOGL        GOOGL
# 1                       Date          NaN          NaN          NaN
# 2  2020-01-02 00:00:00+00:00  68.18682098  68.43399811  68.43399811
# 3  2020-01-03 00:00:00+00:00  67.83010101   68.0759964      68.6875
# 4  2020-01-06 00:00:00+00:00  69.63805389  69.89050293  69.91600037
#
#            Low         Open    Volume
# 0        GOOGL        GOOGL     GOOGL
# 1          NaN          NaN       NaN
# 2  67.32450104  67.42050171  27278000
# 3  67.36599731  67.40000153  23408000
# 4  67.55000305  67.58149719  46768000
#                        Date  Adj Close      Close       High        Low  \
# 0 2020-01-02 00:00:00+00:00  68.186821  68.433998  68.433998  67.324501
# 1 2020-01-03 00:00:00+00:00  67.830101  68.075996  68.687500  67.365997
# 2 2020-01-06 00:00:00+00:00  69.638054  69.890503  69.916000  67.550003
# 3 2020-01-07 00:00:00+00:00  69.503548  69.755501  70.175003  69.578003
# 4 2020-01-08 00:00:00+00:00  69.998253  70.251999  70.592499  69.631500
#
#         Open    Volume
# 0  67.420502  27278000
# 1  67.400002  23408000
# 2  67.581497  46768000
# 3  70.023003  34330000
# 4  69.740997  35314000
# (1198, 60, 1)
# (1198,)
#
# ========================
# TRAINING LSTM MODEL
# ========================
# C:\Users\sai\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 60, 50)              │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 60, 50)              │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,851 (198.64 KB)
#  Trainable params: 50,851 (198.64 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 0.0202 - val_loss: 0.0193
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0035 - val_loss: 0.0095
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0028 - val_loss: 0.0056
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0027 - val_loss: 0.0057
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0025 - val_loss: 0.0087
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0028 - val_loss: 0.0058
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0020 - val_loss: 0.0019
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
#
# ======= LSTM RESULTS =======
# LSTM RMSE : 6.320290789142325
# LSTM MAE : 4.9066010144205725
# LSTM Accuracy : 97.00%
#
# ========================
# TRAINING GRU MODEL
# ========================
# C:\Users\sai\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_6 (GRU)                          │ (None, 60, 50)              │           7,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_7 (GRU)                          │ (None, 60, 50)              │          15,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_8 (GRU)                          │ (None, 50)                  │          15,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 38,601 (150.79 KB)
#  Trainable params: 38,601 (150.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0285 - val_loss: 0.0040
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0018 - val_loss: 0.0016
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BD5BEBD580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
#
# ======= GRU RESULTS =======
# GRU RMSE : 5.66978087657212
# GRU MAE : 4.588692031228841
# GRU Accuracy : 97.26%
#
# ===================================
# LSTM vs GRU COMPARISON
# ===================================
# LSTM Accuracy : 97.00%
# GRU Accuracy : 97.26%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# ===================================
# NEXT DAY STOCK PRICE PREDICTION
# ===================================
# LSTM Predicted Price : 191.61476
# GRU Predicted Price : 187.54225

# %%
df.columns
# Out:
# Index(['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
real_prices[0][0]
# Out:
# 146.3800049
